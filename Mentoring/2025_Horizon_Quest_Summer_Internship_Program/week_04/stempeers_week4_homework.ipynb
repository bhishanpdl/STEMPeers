# %% [markdown]
# # Week 3 & 4 Homework: Data Analysis with Pandas
#
# **Objective:** Practice data cleaning, exploration, and visualization using pandas and matplotlib.
#
# ## Part 1: Data Loading and Exploration (20 points)
#
# First, let's load and examine our dataset:
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Load the data
# df = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/students.csv')
# print(df.head()
#
# # Exploration tasks
# ```
#
# ### Question 1.1 (5 points)
# Print the first 8 rows of the dataframe using `df.head()`. What do you notice about the structure of the data?
#
# ### Question 1.2 (5 points)
# Use `df.info()` to examine the data types and missing values. How many columns contain missing values?
#
# ### Question 1.3 (10 points)
# Calculate basic statistics for numerical columns using `df.describe()`. What's the average math score? How does it compare to science and English?
#
# ## Part 2: Data Cleaning (30 points)
#
# ```python
# # Cleaning tasks
# df_clean = df.copy()
# ```
#
# ### Question 2.1 (10 points)
# Remove all rows with missing values using `df_clean.dropna()`. How many rows were removed?
#
# ### Question 2.2 (10 points)
# Filter the data to only include students aged 15-19 using `df_clean[df_clean['age'].between(15, 19)]`. How many students remain?
#
# ### Question 2.3 (10 points)
# Check for duplicate rows using `df_clean.duplicated().sum()`. Are there any duplicates? If yes, remove them.
#
# ## Part 3: Feature Engineering (20 points)
#
# ```python
# # Feature engineering
# ```
#
# ### Question 3.1 (10 points)
# Create a new column 'total_score' that sums math, science, and English scores.
#
# ### Question 3.2 (10 points)
# Create an 'avg_score' column showing each student's average across all three subjects.
#
# ## Part 4: Analysis (20 points)
#
# ```python
# # Analysis tasks
# ```
#
# ### Question 4.1 (10 points)
# Group the data by city and calculate the average math score for each city. Which city has the highest average?
#
# ### Question 4.2 (10 points)
# Calculate the correlation between math and science scores using `df_clean[['math', 'science']].corr()`. What's the correlation value?
#
# ## Part 5: Visualization (10 points)
#
# ```python
# # Visualization tasks
# plt.figure(figsize=(10, 6))
# ```
#
# ### Question 5.1 (5 points)
# Create a histogram of English scores with 15 bins. Add proper labels.
#
# ### Question 5.2 (5 points)
# Make a scatter plot of math vs. science scores with different colors for each city.
#
# ## Bonus Challenge (10 extra points)
#
# Create a function that takes a student ID as input and returns:
# 1. The student's name and city
# 2. Their best and worst subjects
# 3. Whether they're above or below average in each subject
#
# ```python
# def student_report(student_id):
#     # Your code here
#     return report
#
# # Test your function
# print(student_report(42))
# ```

# %% [markdown]
# # Solution qn1

# %%
url = r"https://github.com/stedy/Machine-Learning-with-R-datasets/blob/master/challenger.csv"
url1 = r"https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/refs/heads/master/challenger.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# kwargs = dict(header=0,sep=',')
kwargs = {}

kwargs = {'header':0,'sep':',','index_col':None}

df = pd.read_csv(url1,**kwargs)
# df.head(n=8)
df.head(8)
# Out:
#    o_ring_ct  distress_ct  temperature  pressure  launch_id
# 0          6            0           66        50          1
# 1          6            1           70        50          2
# 2          6            0           69        50          3
# 3          6            0           68        50          4
# 4          6            0           67        50          5
# 5          6            0           72        50          6
# 6          6            0           73       100          7
# 7          6            0           70       100          8

# %% [markdown]
# # Qn2
#
# ### Question 1.1 (5 points)
# Print the first 8 rows of the dataframe using `df.head()`. What do you notice about the structure of the data?
#
# ### Question 1.2 (5 points)
# Use `df.info()` to examine the data types and missing values. How many columns contain missing values?
#
# ### Question 1.3 (10 points)
# Calculate basic statistics for numerical columns using `df.describe()`. What's the average math score? How does it compare to science and English?

# %%
df.head(8)
# Out:
#    o_ring_ct  distress_ct  temperature  pressure  launch_id
# 0          6            0           66        50          1
# 1          6            1           70        50          2
# 2          6            0           69        50          3
# 3          6            0           68        50          4
# 4          6            0           67        50          5
# 5          6            0           72        50          6
# 6          6            0           73       100          7
# 7          6            0           70       100          8

# %%
df.shape
# Out:
# (23, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   o_ring_ct    23 non-null     int64
#  1   distress_ct  23 non-null     int64
#  2   temperature  23 non-null     int64
#  3   pressure     23 non-null     int64
#  4   launch_id    23 non-null     int64
# dtypes: int64(5)
# memory usage: 1.0 KB

# %%
df.describe()
# Out:
#        o_ring_ct  distress_ct  temperature    pressure  launch_id
# count       23.0    23.000000    23.000000   23.000000   23.00000
# mean         6.0     0.304348    69.565217  152.173913   12.00000
# std          0.0     0.558796     7.057080   68.221332    6.78233
# min          6.0     0.000000    53.000000   50.000000    1.00000
# 25%          6.0     0.000000    67.000000   75.000000    6.50000
# 50%          6.0     0.000000    70.000000  200.000000   12.00000
# 75%          6.0     0.500000    75.000000  200.000000   17.50000
# max          6.0     2.000000    81.000000  200.000000   23.00000

# %% [markdown]
# ## Part 2: Data Cleaning (30 points)
#
# ```python
# # Cleaning tasks
# df_clean = df.copy()
# ```
#
# ### Question 2.1 (10 points)
# Remove all rows with missing values using `df_clean.dropna()`. How many rows were removed?
#
# ### Question 2.2 (10 points)
# Filter the data to only include students aged 15-19 using `df_clean[df_clean['age'].between(15, 19)]`. How many students remain?
#
# ### Question 2.3 (10 points)
# Check for duplicate rows using `df_clean.duplicated().sum()`. Are there any duplicates? If yes, remove them.

# %%
df_old = df.copy(deep=True)

# %%
df_backup = df.copy(deep=True)

# %%
df_clean = df.copy()

# %%
# nan = not a number
# na

# %%
print( [i for i in dir(pd.DataFrame) if 'na' in i if i[0] !='_' ])
# Out:
# ['dropna', 'fillna', 'isna', 'notna', 'rename', 'rename_axis']

# %%
df.dropna(how='all').head(2)
# Out:
#    o_ring_ct  distress_ct  temperature  pressure  launch_id
# 0          6            0           66        50          1
# 1          6            1           70        50          2

# %%
df.dropna(how='any').head(2)
# Out:
#    o_ring_ct  distress_ct  temperature  pressure  launch_id
# 0          6            0           66        50          1
# 1          6            1           70        50          2

# %%
_ = df.dropna(subset=['o_ring_ct'])

# %% [markdown]
# Question 3.1 (10 points)
# Create a new column 'total_score' that sums math, science, and English scores.
#
# Question 3.2 (10 points)
# Create an 'avg_score' column showing each student's average across all three subjects.

# %%
# df['new_column'] = df['math'] + df['science'] + df['english']

# %%
df['new'] = df[df.columns[0]] = df[df.columns[1]]
df.head(2)
# Out:
#    o_ring_ct  distress_ct  temperature  pressure  launch_id  new
# 0          0            0           66        50          1    0
# 1          1            1           70        50          2    1

# %%
# sql: AVG(MY_COLUMN)
# PANDAS: df.mycolumn.mean()
# df['mycolumn'].mean()

import numpy as np

# %%
# mock data with cricketers and missing values
data = {
    'name': ['Gill', 'Pant', 'Jadeja', 'Rahul', 'Kohli', 'Rohit', 'Bumrah', 'Jaiswal', 'Siraj', 'Karun'],
    'age': [21, 15, 13, 24, 18, 16, 19, 33, 17, 19],
    'study_hours': [5, 3, 8, np.nan, 6, 4, np.nan, 6, 8, 7],
    'math_grade': [85, 70, 95, 65, 88, np.nan, 86, 93, 76, 87],
    'science_grade': [81, 76, 92, 93, 87, 67, 70, 91, 96, np.nan],
    'english_grade': [94, 95, np.nan, 82, 85, 97, 100, 85, 96, 79],
    'city': ['New York', 'Boston', 'Boston', 'New York', 'Dallas', 'Boston', 'Dallas', 'Dallas', 'New York', 'Dallas']
}

df = pd.DataFrame(data)
df
# Out:
#       name  age  study_hours  math_grade  science_grade  english_grade  \
# 0     Gill   21          5.0        85.0           81.0           94.0
# 1     Pant   15          3.0        70.0           76.0           95.0
# 2   Jadeja   13          8.0        95.0           92.0            NaN
# 3    Rahul   24          NaN        65.0           93.0           82.0
# 4    Kohli   18          6.0        88.0           87.0           85.0
# 5    Rohit   16          4.0         NaN           67.0           97.0
# 6   Bumrah   19          NaN        86.0           70.0          100.0
# 7  Jaiswal   33          6.0        93.0           91.0           85.0
# 8    Siraj   17          8.0        76.0           96.0           96.0
# 9    Karun   19          7.0        87.0            NaN           79.0
#
#        city
# 0  New York
# 1    Boston
# 2    Boston
# 3  New York
# 4    Dallas
# 5    Boston
# 6    Dallas
# 7    Dallas
# 8  New York
# 9    Dallas

# %% [markdown]
# Question 4.1 (10 points)
# Group the data by city and calculate the average math score for each city. Which city has the highest average?
#
# Question 4.2 (10 points)
# Calculate the correlation between math and science scores using df_clean[['math', 'science']].corr(). What's the correlation value?

# %%
df.columns
# Out:
# Index(['name', 'age', 'study_hours', 'math grade', 'science grade',
#        'english grade', 'city'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    name  age  study_hours  math grade  science grade  english grade      city
# 0  Gill   21          5.0        85.0           81.0           94.0  New York

# %%
dfx = df.groupby('city')['math_grade'].mean().reset_index()
dfx
# Out:
#        city  math_grade
# 0    Boston   82.500000
# 1    Dallas   88.500000
# 2  New York   75.333333

# %%
dfx.sort_values('math_grade',ascending=False)
# Out:
#        city  math_grade
# 1    Dallas   88.500000
# 0    Boston   82.500000
# 2  New York   75.333333

# %%
dfx.sort_values('math_grade',ascending=False).head(1)
# Out:
#        city  math_grade
# 1    Dallas   88.500000
# 0    Boston   82.500000
# 2  New York   75.333333

# %%
(df.groupby('city')['math_grade'].mean()
.reset_index()
.sort_values('math_grade',ascending=False)
.head(1)
)
# Out:
#      city  math_grade
# 1  Dallas        88.5

# %%
df.head(1)
# Out:
#    name  age  study_hours  math_grade  science_grade  english_grade      city
# 0  Gill   21          5.0        85.0           81.0           94.0  New York

# %%
df[['age','math_grade']].corr(method='pearson')
# Out:
#                  age  math_grade
# age         1.000000    0.093209
# math_grade  0.093209    1.000000

# %%
df[['age','math_grade']].corr(method='spearman')
# Out:
#                  age  math_grade
# age         1.000000   -0.108788
# math_grade -0.108788    1.000000
