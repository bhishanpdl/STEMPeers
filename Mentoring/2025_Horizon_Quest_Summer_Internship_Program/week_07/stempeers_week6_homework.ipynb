# %% [markdown]
# ## 🧠 Homework: Linear Regression (Week 6 – Hands-On Coding)
#
# ### **Question 1: Predicting Ice Cream Sales from Temperature**
# ```python
# def train_ice_cream_model(temp, sales):
#     """
#     Trains a linear regression model using scikit-learn to predict ice cream sales based on temperature.
#
#     Parameters:
#     - temp: numpy array of shape (n_samples, 1), daily temperature in °F
#     - sales: numpy array of shape (n_samples,), ice cream sales in dollars
#
#     Returns:
#     - model: trained LinearRegression object
#     """
#     pass  # TODO: Fit and return the model
# ```
#
# **Task:**
# Use the following data:
#
# ```python
# temp = np.array([[60], [65], [70], [75], [80], [85], [90]])
# sales = np.array([120, 150, 180, 200, 230, 260, 300])
# ```
#
# Train a model using scikit-learn.
# Predict ice cream sales on a **95°F day**.
# Plot actual vs. predicted sales.
#
# ---
#
# ### **Question 2: Predicting Movie Revenue from Budget**
# ```python
# def train_movie_model(budget, revenue):
#     """
#     Trains a linear regression model using scikit-learn to predict movie revenue from budget.
#
#     Parameters:
#     - budget: numpy array of shape (n_samples, 1), movie budgets in millions
#     - revenue: numpy array of shape (n_samples,), box office revenue in millions
#
#     Returns:
#     - model: trained LinearRegression object
#     """
#     pass  # TODO: Fit and return the model
# ```
#
# **Task:**
# Use this dataset:
#
# ```python
# budget = np.array([[50], [80], [100], [120], [150], [200]])
# revenue = np.array([100, 160, 180, 220, 260, 310])
# ```
#
# Train a scikit-learn model.
# Predict revenue for a movie with a **$175M budget**.
# Plot budget vs. predicted revenue.
#
# ---
#
# ### **Question 3: Feature Engineering with Student Scores**
# ```python
# def add_study_features(X):
#     """
#     Adds new features to a student study dataset:
#     - hours * sleep
#     - hours squared
#
#     Parameters:
#     - X: numpy array of shape (n_samples, 2), columns: [hours studied, hours slept]
#
#     Returns:
#     - X_new: numpy array with original and new features
#     """
#     pass  # TODO: Add features and return updated array
# ```
#
# **Task:**
# Use this dataset:
#
# ```python
# X = np.array([[2, 6], [3, 7], [4, 5], [5, 6], [6, 5]])
# y = np.array([60, 65, 70, 75, 80])
# ```
#
# Add the new features and train a model to predict test scores.
# Compare RMSE before and after feature engineering.
# Which model performs better?
#
# ---
#
# ### **Question 4: Salary Prediction and Evaluation**
# ```python
# def evaluate_salary_model(experience, salary):
#     """
#     Trains and evaluates a salary prediction model using scikit-learn.
#
#     Parameters:
#     - experience: numpy array of shape (n_samples, 1), years of experience
#     - salary: numpy array of shape (n_samples,), actual salaries
#
#     Returns:
#     - metrics: dictionary with 'MSE', 'RMSE', 'MAE'
#     """
#     pass  # TODO: Train model and compute metrics
# ```
#
# **Task:**
# Use this dataset:
#
# ```python
# experience = np.array([[1], [2], [3], [4], [5], [6]])
# salary = np.array([40, 45, 50, 55, 60, 65])
# ```
#
# Train a scikit-learn model.
# Evaluate it using:
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - Mean Absolute Error (MAE)
#
# Which metric is easiest to interpret?
#
# ---
#
# ### **Question 5: Predicting Bike Rentals from Weather**
# ```python
# def train_bike_model(X, y):
#     """
#     Trains a linear regression model to predict bike rentals based on weather features.
#
#     Parameters:
#     - X: numpy array of shape (n_samples, n_features), columns: [temperature, humidity]
#     - y: numpy array of shape (n_samples,), number of rentals
#
#     Returns:
#     - model: trained LinearRegression object
#     """
#     pass  # TODO: Fit and return the model
# ```
#
# **Task:**
# Use this dataset:
#
# ```python
# X = np.array([[60, 80], [65, 70], [70, 60], [75, 50], [80, 40]])
# y = np.array([100, 150, 200, 250, 300])
# ```
#
# Train a model to predict bike rentals.
# Predict rentals on a **78°F day with 45% humidity**.
# Plot predictions and discuss how weather affects rentals.
